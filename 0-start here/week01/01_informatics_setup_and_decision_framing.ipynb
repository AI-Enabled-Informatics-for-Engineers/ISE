# %% [markdown]
# # Week 1 – Informatics Foundations & Cloud Setup
# This notebook introduces informatics as decision engineering and verifies your coding environment.
#
# **Learning goals:**
# - Understand data → information → decision → action
# - Verify cloud / notebook access

# %%
# Environment check
import sys
print(sys.version)

# %% [markdown]
# ## Simple Decision Framing Example
# We load a small dataset and discuss what decisions it supports.

# %%
import pandas as pd

data = {
    'machine_id': [1,1,2,2,3],
    'temperature': [72,75,80,85,78],
    'failure': [0,0,1,1,0]
}
df = pd.DataFrame(data)
df

# %% [markdown]
# ### Reflection
# - What decision could this data support?
# - What happens if the decision is late or wrong?
